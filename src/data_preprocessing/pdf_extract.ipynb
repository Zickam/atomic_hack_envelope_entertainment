# %%
from PyPDF2 import PdfReader

# %%
with open(
        '../data/dataset/Для Хакатона/Инструкция D-1C1-1.03.04 Выпуск продукции услуг работ собственным производством (НФ) (5) (2).pdf',
        'rb') as f:
    reader = PdfReader(f)

    text = ''

    for page_num in range(len(reader.pages)):
        page = reader.pages[page_num]
        text += page.extract_text().replace('\n', '')

# %%
text
# Out:
# 'а    Проект D-1C1-1 «Развитие унифицированной отраслевой платформы «1С ERP 2.0: ЦИФРОВОЙ РОСАТОМ»  Инструкция пользователей  «D-1C1-1.03.04 Выпуск продукции, услуг, работ собственным производством»   Инструкция пользователей D-1C1-1.03.04  Выпуск продукции, услуг, работ собственным производ ством Автор АО «ГРИНАТОМ» Инструкция пользователей «D-1C1-1.03.04 Выпуск продукции, услуг, работ собственным производством» Страница 2 Страниц 26 Версия  6  ЛИСТ ИЗМЕНЕНИЙ  Дата Версия  Краткое описание изменений ФИО 10.12.2020 1 Разработка первой версии документа Смоляков Р.А. 30.07.2021 2 Добавлено описание оформления документа «Производство без заказа» Ивлев А.В. 02.08.2021 3 Изменение форматирования Неумоина А.В. 10.02.2022 4 Замена рис. 60 Омарова Б.А. 12.08.2022 5 Документ переработан под версию 1С:ERP 2.5.7 Елкина А.В. 02.09.2022 6 Изменение форматирования Николаенко Ю.Р.      Инструкция пользователей D-1C1-1.03.04  Выпуск продукции, услуг, работ собственным производ ством Автор АО «ГРИНАТОМ» Инструкция пользователей «D-1C1-1.03.04 Выпуск продукции, услуг, работ собственным производством» Страница 3 Страниц 26 Версия  6  СОДЕРЖАНИЕ  ПЕРЕЧЕНЬ СОКРАЩЕНИЙ, ТЕРМИНОВ И ОПРЕДЕЛЕНИЙ ....... ................................. 4  ЦЕЛИ И ЗАДАЧИ НАСТОЯЩЕЙ ИНСТУКЦИИ ................. ............................................... 5  1.  ОПИСАНИЕ ЭТАПОВ БИЗНЕС-ПРОЦЕССА ................... .............................................. 6  1.1  Последовательность этапов бизнес-процесса ......... ................................................... ... 6 1.2  Профили групп доступа ............................. ................................................... .................. 6  1.3  Описание бизнес-процесса .......................... ................................................... ................ 7  1.3.1  Выпуск готовой продукции работ, услуг (Экономист пр оизводства) ................ 7  1.3.1.1  Оформление выпуска продукции через документ «Произв одство без заказа» (попроцессный или попередельный вид произво дства) .................................... 8  1.3.1.2  Оформление выпуска продукции через документ «Заказ на производство» (позаказный вид производства) ....... ................................................... .. 12  1.3.1.3  Оформление выпуска продукции через загрузку данных из внешней системы 19  1.3.2  Определение направления выпуска ГП, работ, услуг (Э кономист производства)  .................................................. ................................................... ............................. 19  1.3.3  Оформление выпуска обслуживающих производств (Эконо мист производства)  .................................................. ................................................... ............................. 21  1.3.4  Проверка документов выпуска и формирование проводок  (Бухгалтер по учету затрат и формированию себестоимости) .............. ............................................... 24      Инструкция пользователей D-1C1-1.03.04  Выпуск продукции, услуг, работ собственным производ ством Автор АО «ГРИНАТОМ» Инструкция пользователей «D-1C1-1.03.04 Выпуск продукции, услуг, работ собственным производством» Страница 4 Страниц 26 Версия  6  ПЕРЕЧЕНЬ СОКР АЩЕНИЙ, ТЕРМИНОВ И ОПРЕДЕЛЕНИЙ Перечень терминов и определений, используемых в док ументе приведен в Таблице 1. Таблица 1. Термины, определения и сокращения  Термин/ сокращение Расшифровка / Определение 1С:ERP  Унифицированная система управления ресурсами предпр иятия на базе «1С: 1С:ERP Управление предприятием 2», построенная в рамках проекта D-1C1-1 ВНА Внеоборотный актив ВРЦ Вид рабочего центра ГП Готовая продукция Давалец Контрагент, который передает собственные материалы для производства продукции МХ Места хранения НМА Нематериальный актив НСИ Нормативно-справочная информация ПБЗ Производство без заказа ПО Программное обеспечение Проект Развитие унифицированной отраслевой платформы «1С E RP 2.0: ЦИФРОВОЙ РОСАТОМ» РЦ Рабочий центр Сч29 Счет 29 плана счетов бухга ...
